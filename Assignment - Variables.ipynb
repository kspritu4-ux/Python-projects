# %%
# Question 1 :  Write a Python program that asks the user to enter a
# temperature and specify whether it's in Celsius or Fahrenheit, converts the temperature to the opposite unit

temp = float(input("Enter temperature: "))
unit = input("C or F? ").strip().upper()

if unit == "C":
    converted = temp * 9/5 + 32
    print(f"{temp}°C is {converted:.2f}°F")
elif unit == "F":
    converted = (temp - 32) * 5/9
    print(f"{temp}°F is {converted:.2f}°C")
else:
    print("Invalid unit. Please enter C or F.")
# Out:
# Enter temperature: 67
# C or F? f
# 67.0°F is 19.44°C

# %%
# Question 2 : Write a Python program to calculate the simple interest for a given principal amount,
# rate of interest, and time by prompting the user for inputs, and outputting both the simple interest and the total amount.

Principal = float(input("Enter the principal amount: "))
rate = float(input("Enter the rate of interest(in%): "))
time = float(input("Enter the time period(in years): "))
simple_interest = (Principal*rate*time)/100
Total_amount = Principal+simple_interest
print(f"simple: {simple_interest}")
print(f"toatl_amount: {Total_amount}")
# Out:
# Enter the principal amount: 64000
# Enter the rate of interest(in%): 6
# Enter the time period(in years): 1
# simple: 3840.0
# toatl_amount: 67840.0

# %%
# Question 3 : Write a Python program that asks the user to enter an amount in their home currency (e.g., USD),
# asks for the target currency (e.g., EUR), uses predefined conversion rates to calculate the equivalent amount,
# and outputs the converted amount in the target currency.

rates = {'USD': 1, 'EUR': 0.85, 'INR': 83, 'JPY': 150, 'GBP': 0.75}

h = input("Home currency: ").upper()
t = input("Target currency: ").upper()
amt = float(input(f"Amount in {h}: "))

if h in rates and t in rates:
    print(f"{amt} {h} = {amt / rates[h] * rates[t]:.2f} {t}")
else:
    print("Currency not supported.")
# Out:
# Home currency: INR
# Target currency: USD
# Amount in INR: 90
# 90.0 INR = 1.08 USD

# %%
# Question 4 : Write a Python program that asks for the user's weight (kg) and height (m),
# calculates the BMI , and outputs the BMI with a category (underweight, normal weight, overweight, or obese)
#  based on standard thresholds.

# Ask for user input
weight = float(input("Enter your weight (kg): "))
height = float(input("Enter your height (m): "))

# Calculate BMI
bmi = weight / (height ** 2)

# Determine category
if bmi < 18.5:
    category = "Underweight"
elif 18.5 <= bmi < 24.9:
    category = "Normal Weight"
elif 25.0 <= bmi < 29.9:
    category = "Overweight"
else:
    category = "Obese"

# Output result
print(f"Your BMI is {bmi:.2f}, which is considered {category}.")
# Out:
# Enter your weight (kg): 55.5
# Enter your height (m): 1.6
# Your BMI is 21.68, which is considered Normal Weight.

# %%
# Question 5 : Write a Python program to convert a user-input distance between miles and kilometers
# and output the converted distance using the conversion factors 1 mile = 1.60934 kilometers and 1 kilometer = 0.621371 miles.

# Ask user for conversion choice
choice = input("Enter 'm' to convert miles to kilometers or 'k' to convert kilometers to miles: ").lower()

if choice == 'm':
    b = float(input("Enter distance in miles: "))
    kms = b * 1.60934
    print("Kilometers:", kms)
elif choice == 'k':
    a = float(input("Enter distance in kilometers: "))
    miles = a * 0.621371
    print("Miles:", miles)
else:
    print("Invalid choice. Please enter 'm' or 'k'.")
# Out:
# Enter 'm' to convert miles to kilometers or 'k' to convert kilometers to miles: M
# Enter distance in miles: 7.8
# Kilometers: 12.552852
